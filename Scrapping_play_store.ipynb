# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import app

import pandas as pd
import numpy as np

# %%
# Scrape All available reviews 
#(DONT RUN THIS CELL!!! RUN ONLY IF YOU WANT TO SCRAPE ALL AVAILABLE REVIEWS)
#JANGAN DI RUN KODE INI, KECUALI ANDA INGIN SCRAPE SEMUA REVIEWS SEKALIGUS

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.gojek.app',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
    count=200,
    filter_score_with=None
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <cell line: 7>()
#       1 # Scrape All available reviews
#       2 #(DONT RUN THIS CELL!!! RUN ONLY IF YOU WANT TO SCRAPE ALL AVAILABLE REVIEWS)
#       3 #JANGAN DI RUN KODE INI, KECUALI ANDA INGIN SCRAPE SEMUA REVIEWS SEKALIGUS
#       5 from google_play_scraper import Sort, reviews_all
# ----> 7 result = reviews_all(
#       8     'com.gojek.app',
#       9     sleep_milliseconds=0, # defaults to 0
#      10     lang='id', # defaults to 'en'
#      11     country='id', # defaults to 'us'
#      12     sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT , you can use Sort.NEWEST to get newst reviews
#      13     count=200,
#      14     filter_score_with=None
#      15 )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google_play_scraper\features\reviews.py:127, in reviews_all(app_id, sleep_milliseconds, **kwargs)
#     124 result = []
#     126 while True:
# --> 127     _result, continuation_token = reviews(
#     128         app_id,
#     129         count=MAX_COUNT_EACH_FETCH,
#     130         continuation_token=continuation_token,
#     131         **kwargs
#     132     )
#     134     result += _result
#     136     if continuation_token.token is None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google_play_scraper\features\reviews.py:91, in reviews(app_id, lang, country, sort, count, filter_score_with, continuation_token)
#      88     _fetch_count = MAX_COUNT_EACH_FETCH
#      90 try:
# ---> 91     review_items, token = _fetch_review_items(
#      92         url, app_id, sort, _fetch_count, filter_score_with, token
#      93     )
#      94 except (TypeError, IndexError):
#      95     token = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google_play_scraper\features\reviews.py:34, in _fetch_review_items(url, app_id, sort, count, filter_score_with, pagination_token)
#      26 def _fetch_review_items(
#      27     url: str,
#      28     app_id: str,
#    (...)
#      32     pagination_token: Optional[str],
#      33 ):
# ---> 34     dom = post(
#      35         url,
#      36         Formats.Reviews.build_body(
#      37             app_id,
#      38             sort,
#      39             count,
#      40             "null" if filter_score_with is None else filter_score_with,
#      41             pagination_token,
#      42         ),
#      43         {"content-type": "application/x-www-form-urlencoded"},
#      44     )
#      46     match = json.loads(Regex.REVIEWS.findall(dom)[0])
#      48     return json.loads(match[0][2])[0], json.loads(match[0][2])[-1][-1]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google_play_scraper\utils\request.py:23, in post(url, data, headers)
#      22 def post(url: str, data: Union[str, bytes], headers: dict) -> str:
# ---> 23     return _urlopen(Request(url, data=data, headers=headers))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\google_play_scraper\utils\request.py:10, in _urlopen(obj)
#       8 def _urlopen(obj):
#       9     try:
# ---> 10         resp = urlopen(obj)
#      11     except HTTPError as e:
#      12         if e.code == 404:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#Scrape desired number of reviews
#Run kode ini jika ingin scrape data dengan jumlah tertentu. Ganti (misal, ingin scrape sejumlah 1000, maka ganti kode , count = 1000 )

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.gojek.app',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=100, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId       userName  \
# 0  0c965fc1-ed59-4fc4-bb5c-e8d364a7936c   Asep Rohendi
# 1  4d112eac-5a78-4d92-98be-3df9bc1d6a0c      Mar'ie El
# 2  5cdc2a89-2379-4e0e-8a81-a01637ff4124      Q2CAR 555
# 3  bfd58f5d-69ae-4b75-8132-ee9bb335b3a5  Suroso Pinang
# 4  edd0419a-7bd6-4c14-bae6-7a919ef3547b    bahrul huda
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AAcHTt...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a/AAcHTt...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0                                    pelayanan bagus      5              0
# 1  gak bisa masuk, padahal sedang dalam keadaan d...      1              0
# 2  yang terbaik gojek pokonya, drivernya sopan² l...      5              0
# 3                                         Luar biasa      5              0
# 4                                              👍👍👍👍👍      5              0
#
#   reviewCreatedVersion                  at  \
# 0               4.68.1 2023-08-13 22:47:15
# 1               4.72.1 2023-08-13 22:44:37
# 2               4.72.1 2023-08-13 22:43:42
# 3               4.72.1 2023-08-13 22:38:14
# 4                 None 2023-08-13 22:32:03
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1  Hai Mar'ie El, mohon maaf atas kendalanya. Seb... 2023-08-14 07:45:20
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     4.68.1
# 1     4.72.1
# 2     4.72.1
# 3     4.72.1
# 4       None

# %%
df_busu.shape
# Out:
# (100, 11)

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#         userName  score                  at  \
# 0   Asep Rohendi      5 2023-08-13 22:47:15
# 1      Mar'ie El      1 2023-08-13 22:44:37
# 2      Q2CAR 555      5 2023-08-13 22:43:42
# 3  Suroso Pinang      5 2023-08-13 22:38:14
# 4    bahrul huda      5 2023-08-13 22:32:03
#
#                                              content
# 0                                    pelayanan bagus
# 1  gak bisa masuk, padahal sedang dalam keadaan d...
# 2  yang terbaik gojek pokonya, drivernya sopan² l...
# 3                                         Luar biasa
# 4                                              👍👍👍👍👍

# %%
#Run This Code to Sort the Data By Date 

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#         userName  score                  at  \
# 0   Asep Rohendi      5 2023-08-13 22:47:15
# 1      Mar'ie El      1 2023-08-13 22:44:37
# 2      Q2CAR 555      5 2023-08-13 22:43:42
# 3  Suroso Pinang      5 2023-08-13 22:38:14
# 4    bahrul huda      5 2023-08-13 22:32:03
#
#                                              content
# 0                                    pelayanan bagus
# 1  gak bisa masuk, padahal sedang dalam keadaan d...
# 2  yang terbaik gojek pokonya, drivernya sopan² l...
# 3                                         Luar biasa
# 4                                              👍👍👍👍👍

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.tail(10)
# Out:
#                          userName  score                  at  \
# 90                  Sutiyono Amin      5 2023-08-13 17:31:59
# 91                       Muyassir      5 2023-08-13 17:27:31
# 92                      hafni tya      5 2023-08-13 17:27:03
# 93                 Yudo Widiyanto      5 2023-08-13 17:14:37
# 94  Muhammad Deyanta Hafidz Iraqi      5 2023-08-13 17:13:46
# 95                     Hp Samsung      5 2023-08-13 17:09:35
# 96                 Savera Anastya      1 2023-08-13 17:08:02
# 97                    Neng Paitah      5 2023-08-13 17:07:51
# 98                     Byan Satya      1 2023-08-13 17:06:03
# 99                agung sudarmono      5 2023-08-13 17:01:36
#
#                                               content
# 90  Mohon diperbaiki GPS karena didlm kita menjemp...
# 91                   Bisa belanja pulsa,token listrik
# 92                                                  👍
# 93                                         Thanks Bro
# 94      Sangat membantu. Mohon banyakin lagi promonya
# 95                                    Sangat membantu
# 96  Gak bisa dibuka apk go jek saya,internet tidak...
# 97                            Oke bgt sangat membantu
# 98  Saya top up pin udh bener tapi gk ad jaringan ...
# 99                                        Lebih bagus

# %%
my_df.to_csv("gojek_scrap_dataset.csv", index= False)
